# %%
import tensorflow as tf
from kaggle_datasets import KaggleDatasets
import numpy as np
print("Tensorflow version " + tf.__version__)
# Out:
# D0628 17:41:47.609417601      15 config.cc:119]                        gRPC EXPERIMENT tcp_frame_size_tuning               OFF (default:OFF)
# D0628 17:41:47.609440775      15 config.cc:119]                        gRPC EXPERIMENT tcp_rcv_lowat                       OFF (default:OFF)
# D0628 17:41:47.609443942      15 config.cc:119]                        gRPC EXPERIMENT peer_state_based_framing            OFF (default:OFF)
# D0628 17:41:47.609446423      15 config.cc:119]                        gRPC EXPERIMENT flow_control_fixes                  ON  (default:ON)
# D0628 17:41:47.609448609      15 config.cc:119]                        gRPC EXPERIMENT memory_pressure_controller          OFF (default:OFF)
# D0628 17:41:47.609451227      15 config.cc:119]                        gRPC EXPERIMENT unconstrained_max_quota_buffer_size OFF (default:OFF)
# D0628 17:41:47.609453698      15 config.cc:119]                        gRPC EXPERIMENT new_hpack_huffman_decoder           ON  (default:ON)
# D0628 17:41:47.609455942      15 config.cc:119]                        gRPC EXPERIMENT event_engine_client                 OFF (default:OFF)
# D0628 17:41:47.609458277      15 config.cc:119]                        gRPC EXPERIMENT monitoring_experiment               ON  (default:ON)
# D0628 17:41:47.609460549      15 config.cc:119]                        gRPC EXPERIMENT promise_based_client_call           OFF (default:OFF)
# D0628 17:41:47.609463158      15 config.cc:119]                        gRPC EXPERIMENT free_large_allocator                OFF (default:OFF)
# D0628 17:41:47.609465418      15 config.cc:119]                        gRPC EXPERIMENT promise_based_server_call           OFF (default:OFF)
# D0628 17:41:47.609467677      15 config.cc:119]                        gRPC EXPERIMENT transport_supplies_client_latency   OFF (default:OFF)
# D0628 17:41:47.609470178      15 config.cc:119]                        gRPC EXPERIMENT event_engine_listener               OFF (default:OFF)
# I0628 17:41:47.609643337      15 ev_epoll1_linux.cc:122]               grpc epoll fd: 61
# D0628 17:41:47.609654268      15 ev_posix.cc:144]                      Using polling engine: epoll1
# D0628 17:41:47.609672127      15 dns_resolver_ares.cc:822]             Using ares dns resolver
# D0628 17:41:47.615671477      15 lb_policy_registry.cc:46]             registering LB policy factory for "priority_experimental"
# D0628 17:41:47.615680480      15 lb_policy_registry.cc:46]             registering LB policy factory for "outlier_detection_experimental"
# D0628 17:41:47.615683645      15 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_target_experimental"
# D0628 17:41:47.615686399      15 lb_policy_registry.cc:46]             registering LB policy factory for "pick_first"
# D0628 17:41:47.615689246      15 lb_policy_registry.cc:46]             registering LB policy factory for "round_robin"
# D0628 17:41:47.615692282      15 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_round_robin_experimental"
# D0628 17:41:47.615698560      15 lb_policy_registry.cc:46]             registering LB policy factory for "ring_hash_experimental"
# D0628 17:41:47.615716037      15 lb_policy_registry.cc:46]             registering LB policy factory for "grpclb"
# D0628 17:41:47.615742174      15 lb_policy_registry.cc:46]             registering LB policy factory for "rls_experimental"
# D0628 17:41:47.615755233      15 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_manager_experimental"
# D0628 17:41:47.615758502      15 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_impl_experimental"
# D0628 17:41:47.615762097      15 lb_policy_registry.cc:46]             registering LB policy factory for "cds_experimental"
# D0628 17:41:47.615765072      15 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_resolver_experimental"
# D0628 17:41:47.615767995      15 lb_policy_registry.cc:46]             registering LB policy factory for "xds_override_host_experimental"
# D0628 17:41:47.615771145      15 lb_policy_registry.cc:46]             registering LB policy factory for "xds_wrr_locality_experimental"
# D0628 17:41:47.615774770      15 certificate_provider_registry.cc:35]  registering certificate provider factory for "file_watcher"
# I0628 17:41:47.618573122      15 socket_utils_common_posix.cc:408]     Disabling AF_INET6 sockets because ::1 is not available.
# I0628 17:41:47.634042306     317 socket_utils_common_posix.cc:337]     TCP_USER_TIMEOUT is available. TCP_USER_TIMEOUT will be used thereafter
# E0628 17:41:47.640615906     317 oauth2_credentials.cc:236]            oauth_fetch: UNKNOWN:C-ares status is not ARES_SUCCESS qtype=A name=metadata.google.internal. is_balancer=0: Domain name not found {created_time:"2023-06-28T17:41:47.640601859+00:00", grpc_status:2}
# Tensorflow version 2.12.0

# %% [markdown]
# # Accelarator Settings

# %%
import tensorflow as tf
import numpy as np
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# Running on TPU
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: local
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# REPLICAS:  8

# %%
IMAGE_SIZE = [224, 224] 
EPOCHS = 50
BATCH_SIZE = 16 * strategy.num_replicas_in_sync

NUM_TRAINING_IMAGES = 12753
NUM_TEST_IMAGES = 7382
STEPS_PER_EPOCH = NUM_TRAINING_IMAGES // BATCH_SIZE

# %% [markdown]
# # Data Loaders

# %%
AUTO = tf.data.experimental.AUTOTUNE
def data_augment(image, label):
    image = tf.image.random_flip_left_right(image)
    return image, label 
def decode_image(image_data):
    image = tf.image.decode_jpeg(image_data, channels=3)
    image = tf.keras.applications.efficientnet.preprocess_input(image)
    #image = tf.cast(image, tf.float32) / 255.0  # convert image to floats in [0, 1] range
    image = tf.reshape(image, [*IMAGE_SIZE, 3]) # explicit size needed for TPU
    return image

def read_labeled_tfrecord(example):
    LABELED_TFREC_FORMAT = {
        "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
        "class": tf.io.FixedLenFeature([], tf.int64),  # shape [] means single element
    }
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'])
    label = tf.cast(example['class'], tf.int32)
    return image, label # returns a dataset of (image, label) pairs

def load_dataset(filenames, labeled=True, ordered=False):
    # Read from TFRecords. For optimal performance, reading from multiple files at once and
    # disregarding data order. Order does not matter since we will be shuffling the data anyway.

    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False # disable order, increase speed

    dataset = tf.data.TFRecordDataset(filenames) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(read_labeled_tfrecord)
    # returns a dataset of (image, label) pairs if labeled=True or (image, id) pairs if labeled=False
    return dataset

def get_training_dataset():
    dataset = load_dataset(tf.io.gfile.glob('/kaggle/input/tpu-getting-started/tfrecords-jpeg-224x224/train/*.tfrec'), labeled=True)
    dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
    dataset = dataset.repeat() # the training dataset must repeat for several epochs
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO)
    return dataset

def get_validation_dataset():
    dataset = load_dataset(tf.io.gfile.glob('/kaggle/input/tpu-getting-started/tfrecords-jpeg-224x224/val/*.tfrec'), labeled=True, ordered=False)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.cache()
    dataset = dataset.prefetch(AUTO)
    return dataset


training_dataset = get_training_dataset()
validation_dataset = get_validation_dataset()

# %% [markdown]
# # Model

# %%
with strategy.scope():    
    pretrained_model = tf.keras.applications.efficientnet.EfficientNetB5(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
    pretrained_model.trainable = False # tramsfer learning
    
    model = tf.keras.Sequential([
        pretrained_model,
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(104, activation='softmax')
    ])
        
model.compile(
    optimizer='adam',
    loss = 'sparse_categorical_crossentropy',
    metrics=['sparse_categorical_accuracy']
)

historical = model.fit(training_dataset, 
          steps_per_epoch=STEPS_PER_EPOCH, 
          epochs=EPOCHS, 
          validation_data=validation_dataset)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115263384/115263384 [==============================] - 1s 0us/step
# Epoch 1/50
# 2023-06-28 17:45:14.678006: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp.
# 2023-06-28 17:45:15.401350: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp.
# 99/99 [==============================] - ETA: 0s - loss: 2.6011 - sparse_categorical_accuracy: 0.4370
# 2023-06-28 17:45:51.697228: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp.
# 2023-06-28 17:45:52.153483: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp.
# 99/99 [==============================] - 82s 333ms/step - loss: 2.6011 - sparse_categorical_accuracy: 0.4370 - val_loss: 1.6466 - val_sparse_categorical_accuracy: 0.6188
# Epoch 2/50
# 99/99 [==============================] - 7s 75ms/step - loss: 1.3743 - sparse_categorical_accuracy: 0.6940 - val_loss: 1.1866 - val_sparse_categorical_accuracy: 0.7271
# Epoch 3/50
# 99/99 [==============================] - 8s 79ms/step - loss: 1.0385 - sparse_categorical_accuracy: 0.7636 - val_loss: 0.9976 - val_sparse_categorical_accuracy: 0.7637
# Epoch 4/50
# 99/99 [==============================] - 7s 75ms/step - loss: 0.8658 - sparse_categorical_accuracy: 0.7983 - val_loss: 0.8909 - val_sparse_categorical_accuracy: 0.7880
# Epoch 5/50
# 99/99 [==============================] - 7s 76ms/step - loss: 0.7496 - sparse_categorical_accuracy: 0.8267 - val_loss: 0.8276 - val_sparse_categorical_accuracy: 0.7945
# Epoch 6/50
# 99/99 [==============================] - 7s 75ms/step - loss: 0.6692 - sparse_categorical_accuracy: 0.8428 - val_loss: 0.7752 - val_sparse_categorical_accuracy: 0.8079
# Epoch 7/50
# 99/99 [==============================] - 7s 75ms/step - loss: 0.6000 - sparse_categorical_accuracy: 0.8593 - val_loss: 0.7460 - val_sparse_categorical_accuracy: 0.8093
# Epoch 8/50
# 99/99 [==============================] - 7s 74ms/step - loss: 0.5567 - sparse_categorical_accuracy: 0.8716 - val_loss: 0.7189 - val_sparse_categorical_accuracy: 0.8192
# Epoch 9/50
# 99/99 [==============================] - 7s 75ms/step - loss: 0.5093 - sparse_categorical_accuracy: 0.8837 - val_loss: 0.6914 - val_sparse_categorical_accuracy: 0.8279
# Epoch 10/50
# 99/99 [==============================] - 7s 74ms/step - loss: 0.4690 - sparse_categorical_accuracy: 0.8942 - val_loss: 0.6780 - val_sparse_categorical_accuracy: 0.8276
# Epoch 11/50
# 99/99 [==============================] - 7s 75ms/step - loss: 0.4381 - sparse_categorical_accuracy: 0.8997 - val_loss: 0.6661 - val_sparse_categorical_accuracy: 0.8289
# Epoch 12/50
# 99/99 [==============================] - 8s 77ms/step - loss: 0.4116 - sparse_categorical_accuracy: 0.9081 - val_loss: 0.6528 - val_sparse_categorical_accuracy: 0.8327
# Epoch 13/50
# 99/99 [==============================] - 8s 77ms/step - loss: 0.3898 - sparse_categorical_accuracy: 0.9158 - val_loss: 0.6384 - val_sparse_categorical_accuracy: 0.8386
# Epoch 14/50
# 99/99 [==============================] - 8s 78ms/step - loss: 0.3650 - sparse_categorical_accuracy: 0.9200 - val_loss: 0.6328 - val_sparse_categorical_accuracy: 0.8359
# Epoch 15/50
# 99/99 [==============================] - 8s 78ms/step - loss: 0.3493 - sparse_categorical_accuracy: 0.9201 - val_loss: 0.6215 - val_sparse_categorical_accuracy: 0.8384
# Epoch 16/50
# 99/99 [==============================] - 8s 78ms/step - loss: 0.3216 - sparse_categorical_accuracy: 0.9308 - val_loss: 0.6162 - val_sparse_categorical_accuracy: 0.8402
# Epoch 17/50
# 99/99 [==============================] - 8s 79ms/step - loss: 0.3114 - sparse_categorical_accuracy: 0.9337 - val_loss: 0.6055 - val_sparse_categorical_accuracy: 0.8416
# Epoch 18/50
# 99/99 [==============================] - 8s 78ms/step - loss: 0.2972 - sparse_categorical_accuracy: 0.9362 - val_loss: 0.6053 - val_sparse_categorical_accuracy: 0.8443
# Epoch 19/50
# 99/99 [==============================] - 8s 77ms/step - loss: 0.2829 - sparse_categorical_accuracy: 0.9414 - val_loss: 0.6053 - val_sparse_categorical_accuracy: 0.8438
# Epoch 20/50
# 99/99 [==============================] - 9s 86ms/step - loss: 0.2720 - sparse_categorical_accuracy: 0.9426 - val_loss: 0.5972 - val_sparse_categorical_accuracy: 0.8440
# Epoch 21/50
# 99/99 [==============================] - 8s 81ms/step - loss: 0.2561 - sparse_categorical_accuracy: 0.9455 - val_loss: 0.5922 - val_sparse_categorical_accuracy: 0.8505
# Epoch 22/50
# 99/99 [==============================] - 8s 79ms/step - loss: 0.2466 - sparse_categorical_accuracy: 0.9481 - val_loss: 0.5898 - val_sparse_categorical_accuracy: 0.8486
# Epoch 23/50
# 99/99 [==============================] - 8s 79ms/step - loss: 0.2303 - sparse_categorical_accuracy: 0.9523 - val_loss: 0.5862 - val_sparse_categorical_accuracy: 0.8475
# Epoch 24/50
# 99/99 [==============================] - 8s 78ms/step - loss: 0.2263 - sparse_categorical_accuracy: 0.9542 - val_loss: 0.5884 - val_sparse_categorical_accuracy: 0.8483
# Epoch 25/50
# 99/99 [==============================] - 8s 78ms/step - loss: 0.2205 - sparse_categorical_accuracy: 0.9544 - val_loss: 0.5811 - val_sparse_categorical_accuracy: 0.8486
# Epoch 26/50
# 99/99 [==============================] - 8s 78ms/step - loss: 0.2143 - sparse_categorical_accuracy: 0.9557 - val_loss: 0.5828 - val_sparse_categorical_accuracy: 0.8491
# Epoch 27/50
# 99/99 [==============================] - 8s 80ms/step - loss: 0.2020 - sparse_categorical_accuracy: 0.9594 - val_loss: 0.5762 - val_sparse_categorical_accuracy: 0.8489
# Epoch 28/50
# 99/99 [==============================] - 8s 77ms/step - loss: 0.1979 - sparse_categorical_accuracy: 0.9603 - val_loss: 0.5770 - val_sparse_categorical_accuracy: 0.8499
# Epoch 29/50
# 99/99 [==============================] - 8s 78ms/step - loss: 0.1855 - sparse_categorical_accuracy: 0.9619 - val_loss: 0.5724 - val_sparse_categorical_accuracy: 0.8524
# Epoch 30/50
# 99/99 [==============================] - 8s 78ms/step - loss: 0.1781 - sparse_categorical_accuracy: 0.9661 - val_loss: 0.5745 - val_sparse_categorical_accuracy: 0.8521
# Epoch 31/50
# 99/99 [==============================] - 8s 78ms/step - loss: 0.1727 - sparse_categorical_accuracy: 0.9661 - val_loss: 0.5723 - val_sparse_categorical_accuracy: 0.8499
# Epoch 32/50
# 99/99 [==============================] - 8s 79ms/step - loss: 0.1723 - sparse_categorical_accuracy: 0.9654 - val_loss: 0.5744 - val_sparse_categorical_accuracy: 0.8524
# Epoch 33/50
# 99/99 [==============================] - 8s 78ms/step - loss: 0.1653 - sparse_categorical_accuracy: 0.9672 - val_loss: 0.5725 - val_sparse_categorical_accuracy: 0.8529
# Epoch 34/50
# 99/99 [==============================] - 8s 78ms/step - loss: 0.1563 - sparse_categorical_accuracy: 0.9720 - val_loss: 0.5736 - val_sparse_categorical_accuracy: 0.8521
# Epoch 35/50
# 99/99 [==============================] - 8s 77ms/step - loss: 0.1537 - sparse_categorical_accuracy: 0.9710 - val_loss: 0.5697 - val_sparse_categorical_accuracy: 0.8553
# Epoch 36/50
# 99/99 [==============================] - 8s 78ms/step - loss: 0.1494 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.5692 - val_sparse_categorical_accuracy: 0.8543
# Epoch 37/50
# 99/99 [==============================] - 8s 78ms/step - loss: 0.1465 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.5737 - val_sparse_categorical_accuracy: 0.8537
# Epoch 38/50
# 99/99 [==============================] - 9s 87ms/step - loss: 0.1381 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.5724 - val_sparse_categorical_accuracy: 0.8561
# Epoch 39/50
# 99/99 [==============================] - 8s 81ms/step - loss: 0.1345 - sparse_categorical_accuracy: 0.9762 - val_loss: 0.5680 - val_sparse_categorical_accuracy: 0.8543
# Epoch 40/50
# 99/99 [==============================] - 8s 79ms/step - loss: 0.1280 - sparse_categorical_accuracy: 0.9777 - val_loss: 0.5704 - val_sparse_categorical_accuracy: 0.8532
# Epoch 41/50
# 99/99 [==============================] - 8s 76ms/step - loss: 0.1261 - sparse_categorical_accuracy: 0.9789 - val_loss: 0.5664 - val_sparse_categorical_accuracy: 0.8564
# Epoch 42/50
# 99/99 [==============================] - 7s 76ms/step - loss: 0.1229 - sparse_categorical_accuracy: 0.9789 - val_loss: 0.5680 - val_sparse_categorical_accuracy: 0.8559
# Epoch 43/50
# 99/99 [==============================] - 7s 76ms/step - loss: 0.1189 - sparse_categorical_accuracy: 0.9800 - val_loss: 0.5702 - val_sparse_categorical_accuracy: 0.8532
# Epoch 44/50
# 99/99 [==============================] - 8s 76ms/step - loss: 0.1201 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.5689 - val_sparse_categorical_accuracy: 0.8543
# Epoch 45/50
# 99/99 [==============================] - 8s 76ms/step - loss: 0.1147 - sparse_categorical_accuracy: 0.9787 - val_loss: 0.5697 - val_sparse_categorical_accuracy: 0.8537
# Epoch 46/50
# 99/99 [==============================] - 7s 75ms/step - loss: 0.1108 - sparse_categorical_accuracy: 0.9822 - val_loss: 0.5703 - val_sparse_categorical_accuracy: 0.8559
# Epoch 47/50
# 99/99 [==============================] - 8s 76ms/step - loss: 0.1116 - sparse_categorical_accuracy: 0.9789 - val_loss: 0.5672 - val_sparse_categorical_accuracy: 0.8551
# Epoch 48/50
# 99/99 [==============================] - 7s 76ms/step - loss: 0.1033 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.5667 - val_sparse_categorical_accuracy: 0.8564
# Epoch 49/50
# 99/99 [==============================] - 7s 75ms/step - loss: 0.1004 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.5661 - val_sparse_categorical_accuracy: 0.8572
# Epoch 50/50
# 99/99 [==============================] - 7s 75ms/step - loss: 0.1012 - sparse_categorical_accuracy: 0.9818 - val_loss: 0.5694 - val_sparse_categorical_accuracy: 0.8570
